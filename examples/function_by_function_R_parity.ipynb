# %% [markdown]
# # R ↔ Python Function Mapping
#
# Dictionary mapping between R Augur and pyaugur functions.

# %%
import pandas as pd

# %% [markdown]
# ## Function Mapping Table

# %%
mapping = pd.DataFrame([
    {
        'R Function': 'calculate_auc()',
        'Python Function': 'pyaugur.calculate_auc()',
        'R File': 'R/calculate_auc.R',
        'Python File': 'pyaugur/core.py',
        'Description': 'Main entry: train classifier, compute AUC per cell type',
    },
    {
        'R Function': 'calculate_differential_prioritization()',
        'Python Function': 'pyaugur.calculate_differential_prioritization()',
        'R File': 'R/calculate_differential_prioritization.R',
        'Python File': 'pyaugur/differential.py',
        'Description': 'Permutation test for differential prioritization between conditions',
    },
    {
        'R Function': 'select_variance()',
        'Python Function': 'pyaugur.select_variance()',
        'R File': 'R/select_variance.R',
        'Python File': 'pyaugur/feature_selection.py',
        'Description': 'Feature selection by variance (loess on CV vs mean)',
    },
    {
        'R Function': 'select_random()',
        'Python Function': 'pyaugur.select_random()',
        'R File': 'R/select_random.R',
        'Python File': 'pyaugur/feature_selection.py',
        'Description': 'Random feature subsampling',
    },
    {
        'R Function': 'plot_lollipop()',
        'Python Function': '(use matplotlib directly)',
        'R File': 'R/plot_lollipop.R',
        'Python File': '-',
        'Description': 'Lollipop plot of AUC values (use matplotlib barh)',
    },
    {
        'R Function': 'plot_umap()',
        'Python Function': '(use scanpy or matplotlib)',
        'R File': 'R/plot_umap.R',
        'Python File': '-',
        'Description': 'UMAP overlay with AUC (use scanpy.pl.umap)',
    },
    {
        'R Function': 'vfold_cv() [internal]',
        'Python Function': 'sklearn.StratifiedKFold [internal]',
        'R File': 'R/custom_vfold_cv.R',
        'Python File': '(sklearn built-in)',
        'Description': 'Stratified k-fold cross-validation',
    },
])

mapping
# Out:
#                                 R Function  \
# 0                          calculate_auc()
# 1  calculate_differential_prioritization()
# 2                        select_variance()
# 3                          select_random()
# 4                          plot_lollipop()
# 5                              plot_umap()
# 6                    vfold_cv() [internal]
#
#                                    Python Function  \
# 0                          pyaugur.calculate_auc()
# 1  pyaugur.calculate_differential_prioritization()
# 2                        pyaugur.select_variance()
# 3                          pyaugur.select_random()
# 4                        (use matplotlib directly)
# 5                       (use scanpy or matplotlib)
# 6               sklearn.StratifiedKFold [internal]
#
#                                       R File                   Python File  \
# 0                          R/calculate_auc.R               pyaugur/core.py
# ...

# %% [markdown]
# ## Parameter Mapping: `calculate_auc()`

# %%
params = pd.DataFrame([
    {'R Parameter': 'input', 'Python Parameter': 'input', 'Type': 'matrix/AnnData', 'Default': '-', 'Notes': 'Genes × cells matrix or AnnData'},
    {'R Parameter': 'meta', 'Python Parameter': 'meta', 'Type': 'DataFrame', 'Default': 'None', 'Notes': 'Metadata with cell_type and label'},
    {'R Parameter': 'label_col', 'Python Parameter': 'label_col', 'Type': 'str', 'Default': '"label"', 'Notes': 'Column name for condition labels'},
    {'R Parameter': 'cell_type_col', 'Python Parameter': 'cell_type_col', 'Type': 'str', 'Default': '"cell_type"', 'Notes': 'Column name for cell types'},
    {'R Parameter': 'n_subsamples', 'Python Parameter': 'n_subsamples', 'Type': 'int', 'Default': '50', 'Notes': 'Number of random subsamples per cell type'},
    {'R Parameter': 'subsample_size', 'Python Parameter': 'subsample_size', 'Type': 'int', 'Default': '20', 'Notes': 'Cells per condition per subsample'},
    {'R Parameter': 'folds', 'Python Parameter': 'folds', 'Type': 'int', 'Default': '3', 'Notes': 'Number of CV folds'},
    {'R Parameter': 'min_cells', 'Python Parameter': 'min_cells', 'Type': 'int', 'Default': 'None', 'Notes': 'Min cells per cell type (default: subsample_size)'},
    {'R Parameter': 'var_quantile', 'Python Parameter': 'var_quantile', 'Type': 'float', 'Default': '0.5', 'Notes': 'Quantile for variance filter'},
    {'R Parameter': 'feature_perc', 'Python Parameter': 'feature_perc', 'Type': 'float', 'Default': '0.5', 'Notes': 'Fraction of features randomly selected'},
    {'R Parameter': 'n_threads', 'Python Parameter': 'n_threads', 'Type': 'int', 'Default': '4', 'Notes': 'Threads (unused in Python)'},
    {'R Parameter': 'classifier', 'Python Parameter': 'classifier', 'Type': 'str', 'Default': '"rf"', 'Notes': '"rf" or "lr"'},
    {'R Parameter': 'rf_params', 'Python Parameter': 'rf_params', 'Type': 'dict', 'Default': 'None', 'Notes': '{trees, mtry, min_n, importance}'},
    {'R Parameter': 'lr_params', 'Python Parameter': 'lr_params', 'Type': 'dict', 'Default': 'None', 'Notes': '{mixture, penalty}'},
    {'R Parameter': 'augur_mode', 'Python Parameter': 'augur_mode', 'Type': 'str', 'Default': '"default"', 'Notes': '"default", "velocity", or "permute"'},
    {'R Parameter': '-', 'Python Parameter': 'seed', 'Type': 'int', 'Default': '42', 'Notes': 'Python-only: base random seed'},
])

params
# Out:
#        R Parameter Python Parameter            Type      Default  \
# 0            input            input  matrix/AnnData            -
# 1             meta             meta       DataFrame         None
# 2        label_col        label_col             str      "label"
# 3    cell_type_col    cell_type_col             str  "cell_type"
# 4     n_subsamples     n_subsamples             int           50
# 5   subsample_size   subsample_size             int           20
# 6            folds            folds             int            3
# 7        min_cells        min_cells             int         None
# 8     var_quantile     var_quantile           float          0.5
# 9     feature_perc     feature_perc           float          0.5
# 10       n_threads        n_threads             int            4
# 11      classifier       classifier             str         "rf"
# 12       rf_params        rf_params            dict         None
# ...

# %% [markdown]
# ## Naming Convention Mapping

# %%
naming = pd.DataFrame([
    {'R': 'camelCase', 'Python': 'snake_case', 'Example': 'calculateAuc → calculate_auc'},
    {'R': 'randomForest pkg', 'Python': 'sklearn.ensemble.RandomForestClassifier', 'Example': 'ntree → n_estimators'},
    {'R': 'mtry', 'Python': 'max_features', 'Example': 'mtry=2 → max_features=2'},
    {'R': 'set.seed()', 'Python': 'np.random.default_rng()', 'Example': 'seed=42'},
    {'R': 'pbmclapply', 'Python': 'sequential loop', 'Example': 'Single-threaded for stability'},
    {'R': 'yardstick::roc_auc', 'Python': 'sklearn.metrics.roc_auc_score', 'Example': 'Same AUC computation'},
    {'R': 'rsample::vfold_cv', 'Python': 'sklearn.StratifiedKFold', 'Example': 'Stratified k-fold CV'},
    {'R': 'loess()', 'Python': 'statsmodels lowess()', 'Example': 'C-optimized implementation'},
    {'R': 'sparseMatrixStats', 'Python': 'numpy (dense)', 'Example': 'Converted to dense for speed'},
])

naming
# Out:
#                     R                                   Python  \
# 0           camelCase                               snake_case
# 1    randomForest pkg  sklearn.ensemble.RandomForestClassifier
# 2                mtry                             max_features
# 3          set.seed()                  np.random.default_rng()
# 4          pbmclapply                          sequential loop
# 5  yardstick::roc_auc            sklearn.metrics.roc_auc_score
# 6   rsample::vfold_cv                  sklearn.StratifiedKFold
# 7             loess()                     statsmodels lowess()
# 8   sparseMatrixStats                            numpy (dense)
#
#                          Example
# 0   calculateAuc → calculate_auc
# 1           ntree → n_estimators
# 2        mtry=2 → max_features=2
# 3                        seed=42
# 4  Single-threaded for stability
# 5           Same AUC computation
# 6           Stratified k-fold CV
# 7     C-optimized implementation
# ...

# %% [markdown]
# ## Dependency Mapping

# %%
deps = pd.DataFrame([
    {'R Package': 'randomForest', 'Python Package': 'scikit-learn', 'Purpose': 'Random forest classifier'},
    {'R Package': 'glmnet', 'Python Package': 'scikit-learn (LogisticRegression)', 'Purpose': 'Logistic regression with L1'},
    {'R Package': 'rsample', 'Python Package': 'scikit-learn (KFold)', 'Purpose': 'Cross-validation'},
    {'R Package': 'yardstick', 'Python Package': 'scikit-learn (metrics)', 'Purpose': 'Classification metrics'},
    {'R Package': 'recipes', 'Python Package': '(not needed)', 'Purpose': 'Preprocessing (sklearn handles natively)'},
    {'R Package': 'parsnip', 'Python Package': '(not needed)', 'Purpose': 'Model API (sklearn is the API)'},
    {'R Package': 'dplyr/tidyr', 'Python Package': 'pandas', 'Purpose': 'Data manipulation'},
    {'R Package': 'Matrix', 'Python Package': 'scipy.sparse', 'Purpose': 'Sparse matrices'},
    {'R Package': 'lmtest', 'Python Package': 'statsmodels', 'Purpose': 'Cox test for loess comparison'},
    {'R Package': 'pbmcapply', 'Python Package': '(sequential)', 'Purpose': 'Parallel execution with progress'},
    {'R Package': 'ggplot2', 'Python Package': 'matplotlib', 'Purpose': 'Plotting'},
])

deps
# Out:
#        R Package                     Python Package  \
# 0   randomForest                       scikit-learn
# 1         glmnet  scikit-learn (LogisticRegression)
# 2        rsample               scikit-learn (KFold)
# 3      yardstick             scikit-learn (metrics)
# 4        recipes                       (not needed)
# 5        parsnip                       (not needed)
# 6    dplyr/tidyr                             pandas
# 7         Matrix                       scipy.sparse
# 8         lmtest                        statsmodels
# 9      pbmcapply                       (sequential)
# 10       ggplot2                         matplotlib
#
#                                      Purpose
# 0                   Random forest classifier
# 1                Logistic regression with L1
# 2                           Cross-validation
# 3                     Classification metrics
# 4   Preprocessing (sklearn handles natively)
# 5             Model API (sklearn is the API)
# ...

# %% [markdown]
# ## Output Structure Mapping

# %%
output = pd.DataFrame([
    {'R Key': '$AUC', 'Python Key': '["AUC"]', 'Type': 'DataFrame', 'Description': 'Mean AUC per cell type, sorted descending'},
    {'R Key': '$results', 'Python Key': '["results"]', 'Type': 'DataFrame', 'Description': 'Per-subsample, per-fold metrics'},
    {'R Key': '$feature_importance', 'Python Key': '["feature_importance"]', 'Type': 'DataFrame', 'Description': 'Feature importance (MeanDecreaseAccuracy)'},
    {'R Key': '$X', 'Python Key': '["X"]', 'Type': 'ndarray', 'Description': 'Expression matrix (genes × cells)'},
    {'R Key': '$y', 'Python Key': '["y"]', 'Type': 'ndarray', 'Description': 'Condition labels'},
    {'R Key': '$cell_types', 'Python Key': '["cell_types"]', 'Type': 'ndarray', 'Description': 'Cell type labels'},
    {'R Key': '$parameters', 'Python Key': '["parameters"]', 'Type': 'dict', 'Description': 'Parameters used for the run'},
])

output
# Out:
#                  R Key              Python Key       Type  \
# 0                 $AUC                 ["AUC"]  DataFrame
# 1             $results             ["results"]  DataFrame
# 2  $feature_importance  ["feature_importance"]  DataFrame
# 3                   $X                   ["X"]    ndarray
# 4                   $y                   ["y"]    ndarray
# 5          $cell_types          ["cell_types"]    ndarray
# 6          $parameters          ["parameters"]       dict
#
#                                  Description
# 0  Mean AUC per cell type, sorted descending
# 1            Per-subsample, per-fold metrics
# 2  Feature importance (MeanDecreaseAccuracy)
# 3          Expression matrix (genes × cells)
# 4                           Condition labels
# 5                           Cell type labels
# 6                Parameters used for the run
